# %%
# Core Packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from portfolio_optimizer import portfolio_optimizer
from backtest import backtest, display_backtest_results
import warnings
warnings.filterwarnings("ignore")
from IPython.display import display
from typing import List

# data used to replicate paper results
# VTI, AGG, DBC, VIX
start_date = "2010-01-01"
end_date = "2020-06-30"
price_long_paper = pd.read_csv("data_clean/long_format_daily_original_paper_data.csv")
price_long_paper["Date"] = pd.to_datetime(price_long_paper["Date"])
price_long_paper = price_long_paper.loc[(price_long_paper["Date"] >= start_date) & (price_long_paper["Date"] <= end_date), :]
price_wide_paper = price_long_paper.pivot(index='Date', columns='Ticker', values='Price')

# # full data
# start_date = "1995-01-01"
# end_date = "2022-12-31"
# price_long = pd.read_csv("data_clean/long_format_daily.csv")
# price_long["Date"] = pd.to_datetime(price_long["Date"])
# price_long = price_long.loc[(price_long["Date"] >= start_date) & (price_long["Date"] <= end_date), :]

# # very short data for testing
# price_long_test = price_long.loc[(price_long["Date"] >= '2022-01-01'), :]
# price_wide_test = price_long_test.pivot(index='Date', columns='Ticker', values='Price')
# return_wide_test = price_wide_test.pct_change().iloc[1:,:]

# %% [markdown]
# # Replicate Paper Result

# %%
# %%time

# ORIGINAL LSTM
tf.keras.utils.set_random_seed(100)
portfolio_paper = portfolio_optimizer(price_long_paper)
weight_LSTM = portfolio_paper.optimize("LSTM", period = 252)
# Out:
# 1/1 [==============================] - 0s 215ms/step
# 1/1 [==============================] - 0s 209ms/step
# 1/1 [==============================] - 0s 321ms/step
# 1/1 [==============================] - 0s 193ms/step
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000013BC2B03E20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 197ms/step
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000013BC601F370> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 208ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 208ms/step
# successfully optimized portfolio weights
# CPU times: total: 8.64 s
# Wall time: 16.8 s

# %%
# static allocations
weight_alloc_1 = weight_LSTM.copy()
weight_alloc_2 = weight_LSTM.copy()
weight_alloc_3 = weight_LSTM.copy()
weight_alloc_4 = weight_LSTM.copy()
weight_alloc_1["Weight"] = 1/4
weight_alloc_2.loc[weight_alloc_2["Ticker"] == "VTI", "Weight"] = 1/2
weight_alloc_2.loc[weight_alloc_2["Ticker"] == "AGG", "Weight"] = 1/10
weight_alloc_2.loc[weight_alloc_2["Ticker"] == "DBC", "Weight"] = 1/5
weight_alloc_2.loc[weight_alloc_2["Ticker"] == "VIX", "Weight"] = 1/5
weight_alloc_3.loc[weight_alloc_3["Ticker"] == "VTI", "Weight"] = 1/10
weight_alloc_3.loc[weight_alloc_3["Ticker"] == "AGG", "Weight"] = 1/2
weight_alloc_3.loc[weight_alloc_3["Ticker"] == "DBC", "Weight"] = 1/5
weight_alloc_3.loc[weight_alloc_3["Ticker"] == "VIX", "Weight"] = 1/5
weight_alloc_4.loc[weight_alloc_4["Ticker"] == "VTI", "Weight"] = 2/5
weight_alloc_4.loc[weight_alloc_4["Ticker"] == "AGG", "Weight"] = 2/5
weight_alloc_4.loc[weight_alloc_4["Ticker"] == "DBC", "Weight"] = 1/10
weight_alloc_4.loc[weight_alloc_4["Ticker"] == "VIX", "Weight"] = 1/10

# benchmarks
weight_variance = portfolio_paper.optimize("variance", period = 252)
weight_sharpe = portfolio_paper.optimize("sharpe", period = 252)
weight_markowitz3 = portfolio_paper.optimize("markowitz3", period = 252)
weight_DR = portfolio_paper.optimize("divers_ratio", period = 252)
weight_MRC = portfolio_paper.optimize("marginal_risk_contribution", period = 252)
# Out:
# successfully optimized portfolio weights
# successfully optimized portfolio weights
# successfully optimized portfolio weights
# successfully optimized portfolio weights
# successfully optimized portfolio weights

# %%
# %%time
display_backtest_results(
    [weight_alloc_1, 
     weight_alloc_2, 
     weight_alloc_3, 
     weight_alloc_4,
     weight_variance,
     weight_sharpe,
     weight_markowitz3,
     weight_DR,
     weight_MRC,
     weight_LSTM, 
    ], 
    ["Allocation 1", "Allocation 2", "Allocation 3", "Allocation 4", "minVar", "maxSharpe", "Markowitz 3.0", "maxDR", "minMRC", "LSTM"])
# Out:
#                                        Allocation 1  Allocation 2  \
# avg annualized ret                         0.241715      0.221830
# avg annualized std                         0.297687      0.207538
# sharpe ratio                               0.811977      1.068864
# adjusted sharpe ratio                      0.557261      0.003432
# skewness                                   2.596907      2.916277
# excess kurtosis                           24.212207     31.853192
# maximum drawdown                          -0.182366     -0.126222
# maximum drawdown length (days)            89.000000    249.000000
# VaR (95%)                                 -0.022812     -0.015943
# CVaR (95%)                                -0.030872     -0.021658
# effective number of uncorrelated bets      1.604815      1.891181
#
#                                        Allocation 3  Allocation 4     minVar  \
# avg annualized ret                         0.194304      0.140771   0.053237
# avg annualized std                         0.252811      0.096675   0.034375
# sharpe ratio                               0.768573      1.456123   1.548736
# adjusted sharpe ratio                      0.605477     -2.024451  -3.164343
# skewness                                   2.443905      2.891536  -1.126662
# excess kurtosis                           21.341029     34.999354  27.539844
# maximum drawdown                          -0.164534     -0.080612  -0.087113
# maximum drawdown length (days)            89.000000     83.000000  82.000000
# VaR (95%)                                 -0.019591     -0.007292  -0.002882
# CVaR (95%)                                -0.026467     -0.010298  -0.004823
# effective number of uncorrelated bets      1.577825      2.351785   3.073854
#
#                                        maxSharpe  Markowitz 3.0      maxDR  \
# avg annualized ret                      0.099617       0.106874   0.138780
# avg annualized std                      0.059285       0.158691   0.076106
# sharpe ratio                            1.680295       0.673474   1.823509
# adjusted sharpe ratio                  -0.696500      -0.064787  -3.427763
# skewness                                0.368762       3.847136   0.422871
# excess kurtosis                        12.901778      80.853557  21.712677
# maximum drawdown                       -0.103538      -0.240439  -0.144964
# maximum drawdown length (days)         80.000000     132.000000  80.000000
# VaR (95%)                              -0.004903      -0.008209  -0.005794
# CVaR (95%)                             -0.008203      -0.021791  -0.010217
# effective number of uncorrelated bets   2.606153       2.517976   2.184159
#
#                                           minMRC        LSTM
# avg annualized ret                      0.035015    0.196748
# avg annualized std                      0.030779    0.303979
# sharpe ratio                            1.137634    0.647243
# adjusted sharpe ratio                   0.228074    0.656156
# skewness                               -1.123463    1.093406
# excess kurtosis                        10.876209    5.968335
# maximum drawdown                       -0.070101   -0.290893
# maximum drawdown length (days)         96.000000  369.000000
# VaR (95%)                              -0.002842   -0.025345
# CVaR (95%)                             -0.004429   -0.039113
# effective number of uncorrelated bets   1.906171    1.804577
# CPU times: total: 6.23 s
# Wall time: 10.7 s

# %% [markdown]
# # Improvement 1: loss function & L2 Reg

# %%
# %%time

tf.keras.utils.set_random_seed(100)
weight_LSTM_return = portfolio_paper.optimize("LSTM", period = 252, loss = "return")
weight_LSTM_convex = portfolio_paper.optimize("LSTM", period = 252, loss = "convex")
weight_LSTM_reg = portfolio_paper.optimize("LSTM", period = 252, reg = True)
weight_LSTM_convex_reg = portfolio_paper.optimize("LSTM", period = 252, loss = "convex", reg = True)
# Out:
# 1/1 [==============================] - 0s 219ms/step
# 1/1 [==============================] - 0s 405ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 207ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 198ms/step
# 1/1 [==============================] - 0s 211ms/step
# 1/1 [==============================] - 0s 213ms/step
# 1/1 [==============================] - 0s 198ms/step
# 1/1 [==============================] - 0s 215ms/step
# successfully optimized portfolio weights
# 1/1 [==============================] - 0s 205ms/step
# 1/1 [==============================] - 0s 222ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 207ms/step
# 1/1 [==============================] - 0s 198ms/step
# 1/1 [==============================] - 0s 209ms/step
# 1/1 [==============================] - 0s 203ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 192ms/step
# successfully optimized portfolio weights
# 1/1 [==============================] - 0s 210ms/step
# 1/1 [==============================] - 0s 207ms/step
# 1/1 [==============================] - 0s 211ms/step
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 215ms/step
# 1/1 [==============================] - 0s 424ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 200ms/step
# successfully optimized portfolio weights
# 1/1 [==============================] - 0s 237ms/step
# 1/1 [==============================] - 0s 207ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 407ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 194ms/step
# successfully optimized portfolio weights
# CPU times: total: 32.6 s
# Wall time: 1min 6s

# %%
# %%time
display_backtest_results(
    [weight_LSTM,
     weight_LSTM_return,
     weight_LSTM_convex,
     weight_LSTM_reg,
     weight_LSTM_convex_reg
    ],
    ["LSTM_paper", "LSTM_return", "LSTM_convex", "LSTM_l2reg", "LSTM_convex_l2reg"]
)
# Out:
#                                        LSTM_paper  LSTM_return  LSTM_convex  \
# avg annualized ret                       0.196748     0.165916     0.148312
# avg annualized std                       0.303979     0.220888     0.142589
# sharpe ratio                             0.647243     0.751134     1.040137
# adjusted sharpe ratio                    0.656156     0.685293    -3.535701
# skewness                                 1.093406     2.027347     6.115322
# excess kurtosis                          5.968335    14.524906   121.108538
# maximum drawdown                        -0.290893    -0.280263    -0.168196
# maximum drawdown length (days)         369.000000   500.000000   980.000000
# VaR (95%)                               -0.025345    -0.018498    -0.010330
# CVaR (95%)                              -0.039113    -0.027055    -0.015724
# effective number of uncorrelated bets    1.804577     2.022430     2.441638
#
#                                        LSTM_l2reg  LSTM_convex_l2reg
# avg annualized ret                       0.247354           0.168892
# avg annualized std                       0.306461           0.257022
# sharpe ratio                             0.807130           0.657113
# adjusted sharpe ratio                    0.705630           0.643091
# skewness                                 2.303121           1.885629
# excess kurtosis                         16.046724          12.664260
# maximum drawdown                        -0.244050          -0.242923
# maximum drawdown length (days)         307.000000          89.000000
# VaR (95%)                               -0.024516          -0.021796
# CVaR (95%)                              -0.033490          -0.031120
# effective number of uncorrelated bets    1.659321           1.914855
# CPU times: total: 2.38 s
# Wall time: 5.5 s

# %% [markdown]
# # Improvement 2: Structural Change - Autoencoder

# %%
# %%time

tf.keras.utils.set_random_seed(110)
weight_LSTM_autoencoder = portfolio_paper.optimize("LSTM", period = 252, loss = "convex", structure_change = "autoencoder")
# Out:
# 1/1 [==============================] - 0s 210ms/step
# 1/1 [==============================] - 0s 219ms/step
# 1/1 [==============================] - 0s 239ms/step
# 1/1 [==============================] - 0s 212ms/step
# 1/1 [==============================] - 0s 210ms/step
# 1/1 [==============================] - 0s 215ms/step
# 1/1 [==============================] - 0s 420ms/step
# 1/1 [==============================] - 0s 212ms/step
# 1/1 [==============================] - 0s 213ms/step
# 1/1 [==============================] - 0s 241ms/step
# successfully optimized portfolio weights
# CPU times: total: 9.34 s
# Wall time: 18.3 s

# %%
# %%time
display_backtest_results(
    [weight_LSTM,
     weight_LSTM_autoencoder,
    ],
    ["LSTM_paper", "LSTM_autoencoder"]
)
# Out:
#                                        LSTM_paper  LSTM_autoencoder
# avg annualized ret                       0.196748          0.076716
# avg annualized std                       0.303979          0.076734
# sharpe ratio                             0.647243          0.999766
# adjusted sharpe ratio                    0.656156          0.712341
# skewness                                 1.093406          0.169065
# excess kurtosis                          5.968335          7.579461
# maximum drawdown                        -0.290893         -0.129794
# maximum drawdown length (days)         369.000000        118.000000
# VaR (95%)                               -0.025345         -0.007111
# CVaR (95%)                              -0.039113         -0.010651
# effective number of uncorrelated bets    1.804577          2.948473
# CPU times: total: 1.16 s
# Wall time: 2.27 s
