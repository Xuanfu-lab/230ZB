# %%
# Core Packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from portfolio_optimizer import portfolio_optimizer
from backtest import backtest, display_backtest_results
import warnings
warnings.filterwarnings("ignore")
from IPython.display import display
from typing import List

# data used to replicate paper results
# VTI, AGG, DBC, VIX
start_date = "2010-01-01"
end_date = "2020-06-30"
price_long_paper = pd.read_csv("data_clean/long_format_daily_original_paper_data.csv")
price_long_paper["Date"] = pd.to_datetime(price_long_paper["Date"])
price_long_paper = price_long_paper.loc[(price_long_paper["Date"] >= start_date) & (price_long_paper["Date"] <= end_date), :]
price_wide_paper = price_long_paper.pivot(index='Date', columns='Ticker', values='Price')

# %% [markdown]
# # Replicate Paper Result

# %%
# %%time

# ORIGINAL LSTM
tf.keras.utils.set_random_seed(100)
portfolio_paper = portfolio_optimizer(price_long_paper)
weight_LSTM = portfolio_paper.optimize("LSTM", period = 252)
# Out:
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 210ms/step
# 1/1 [==============================] - 0s 202ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 408ms/step
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 198ms/step
# 1/1 [==============================] - 0s 196ms/step
# successfully optimized portfolio weights
# CPU times: total: 9.12 s
# Wall time: 16.4 s

# %%
# static allocations
weight_alloc_1 = weight_LSTM.copy()
weight_alloc_2 = weight_LSTM.copy()
weight_alloc_3 = weight_LSTM.copy()
weight_alloc_4 = weight_LSTM.copy()
weight_alloc_1["Weight"] = 1/4
weight_alloc_2.loc[weight_alloc_2["Ticker"] == "VTI", "Weight"] = 1/2
weight_alloc_2.loc[weight_alloc_2["Ticker"] == "AGG", "Weight"] = 1/10
weight_alloc_2.loc[weight_alloc_2["Ticker"] == "DBC", "Weight"] = 1/5
weight_alloc_2.loc[weight_alloc_2["Ticker"] == "VIX", "Weight"] = 1/5
weight_alloc_3.loc[weight_alloc_3["Ticker"] == "VTI", "Weight"] = 1/10
weight_alloc_3.loc[weight_alloc_3["Ticker"] == "AGG", "Weight"] = 1/2
weight_alloc_3.loc[weight_alloc_3["Ticker"] == "DBC", "Weight"] = 1/5
weight_alloc_3.loc[weight_alloc_3["Ticker"] == "VIX", "Weight"] = 1/5
weight_alloc_4.loc[weight_alloc_4["Ticker"] == "VTI", "Weight"] = 2/5
weight_alloc_4.loc[weight_alloc_4["Ticker"] == "AGG", "Weight"] = 2/5
weight_alloc_4.loc[weight_alloc_4["Ticker"] == "DBC", "Weight"] = 1/10
weight_alloc_4.loc[weight_alloc_4["Ticker"] == "VIX", "Weight"] = 1/10

# benchmarks
weight_variance = portfolio_paper.optimize("variance", period = 252)
weight_sharpe = portfolio_paper.optimize("sharpe", period = 252)
weight_markowitz3 = portfolio_paper.optimize("markowitz3", period = 252)
weight_DR = portfolio_paper.optimize("divers_ratio", period = 252)
weight_MRC = portfolio_paper.optimize("marginal_risk_contribution", period = 252)
# Out:
# successfully optimized portfolio weights
# successfully optimized portfolio weights
# successfully optimized portfolio weights
# successfully optimized portfolio weights
# successfully optimized portfolio weights

# %%
# %%time
display_backtest_results(
    [weight_alloc_1, 
     weight_alloc_2, 
     weight_alloc_3, 
     weight_alloc_4,
     weight_variance,
     weight_sharpe,
     weight_markowitz3,
     weight_DR,
     weight_MRC,
     weight_LSTM, 
    ], 
    ["Allocation 1", "Allocation 2", "Allocation 3", "Allocation 4", "minVar", "maxSharpe", "Markowitz 3.0", "maxDR", "minMRC", "LSTM"])
# Out:
#                                        Allocation 1  Allocation 2  \
# avg annualized ret                         0.241715      0.221830
# avg annualized std                         0.297687      0.207538
# sharpe ratio                               0.811977      1.068864
# adjusted sharpe ratio                      0.557261      0.003432
# skewness                                   2.596907      2.916277
# excess kurtosis                           24.212207     31.853192
# maximum drawdown                          -0.182366     -0.126222
# maximum drawdown length (days)            89.000000    249.000000
# VaR (95%)                                 -0.022812     -0.015943
# CVaR (95%)                                -0.030872     -0.021658
# effective number of uncorrelated bets      1.604815      1.891181
#
#                                        Allocation 3  Allocation 4     minVar  \
# avg annualized ret                         0.194304      0.140771   0.053237
# avg annualized std                         0.252811      0.096675   0.034375
# sharpe ratio                               0.768573      1.456123   1.548736
# adjusted sharpe ratio                      0.605477     -2.024451  -3.164343
# skewness                                   2.443905      2.891536  -1.126662
# excess kurtosis                           21.341029     34.999354  27.539844
# maximum drawdown                          -0.164534     -0.080612  -0.087113
# maximum drawdown length (days)            89.000000     83.000000  82.000000
# VaR (95%)                                 -0.019591     -0.007292  -0.002882
# CVaR (95%)                                -0.026467     -0.010298  -0.004823
# effective number of uncorrelated bets      1.577825      2.351785   3.073854
#
#                                        maxSharpe  Markowitz 3.0      maxDR  \
# avg annualized ret                      0.099617       0.106874   0.138780
# avg annualized std                      0.059285       0.158691   0.076106
# sharpe ratio                            1.680295       0.673474   1.823509
# adjusted sharpe ratio                  -0.696500      -0.064787  -3.427763
# skewness                                0.368762       3.847136   0.422871
# excess kurtosis                        12.901778      80.853557  21.712677
# maximum drawdown                       -0.103538      -0.240439  -0.144964
# maximum drawdown length (days)         80.000000     132.000000  80.000000
# VaR (95%)                              -0.004903      -0.008209  -0.005794
# CVaR (95%)                             -0.008203      -0.021791  -0.010217
# effective number of uncorrelated bets   2.606153       2.517976   2.184159
#
#                                           minMRC        LSTM
# avg annualized ret                      0.035015    0.196748
# avg annualized std                      0.030779    0.303979
# sharpe ratio                            1.137634    0.647243
# adjusted sharpe ratio                   0.228074    0.656156
# skewness                               -1.123463    1.093406
# excess kurtosis                        10.876209    5.968335
# maximum drawdown                       -0.070101   -0.290893
# maximum drawdown length (days)         96.000000  369.000000
# VaR (95%)                              -0.002842   -0.025345
# CVaR (95%)                             -0.004429   -0.039113
# effective number of uncorrelated bets   1.906171    1.804577
# CPU times: total: 5.62 s
# Wall time: 11.1 s

# %% [markdown]
# # Improvement 1: loss function & L2 Reg

# %%
# %%time

tf.keras.utils.set_random_seed(100)
weight_LSTM_return = portfolio_paper.optimize("LSTM", period = 252, loss = "return")
weight_LSTM_convex = portfolio_paper.optimize("LSTM", period = 252, loss = "convex")
weight_LSTM_reg = portfolio_paper.optimize("LSTM", period = 252, reg = True)
weight_LSTM_sortino = portfolio_paper.optimize("LSTM", period = 252, loss = "sortino")
weight_LSTM_sortino_convex = portfolio_paper.optimize("LSTM", period = 252, loss = "sortino_convex")
# Out:
# 1/1 [==============================] - 0s 198ms/step
# 1/1 [==============================] - 0s 205ms/step
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 0s 215ms/step
# 1/1 [==============================] - 0s 204ms/step
# 1/1 [==============================] - 0s 215ms/step
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 206ms/step
# 1/1 [==============================] - 0s 201ms/step
# 1/1 [==============================] - 0s 409ms/step
# successfully optimized portfolio weights
# 1/1 [==============================] - 0s 198ms/step
# 1/1 [==============================] - 0s 201ms/step
# 1/1 [==============================] - 0s 208ms/step
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 0s 210ms/step
# 1/1 [==============================] - 0s 214ms/step
# 1/1 [==============================] - 0s 407ms/step
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 202ms/step
# 1/1 [==============================] - 0s 200ms/step
# successfully optimized portfolio weights
# 1/1 [==============================] - 0s 212ms/step
# 1/1 [==============================] - 0s 206ms/step
# 1/1 [==============================] - 0s 202ms/step
# 1/1 [==============================] - 0s 212ms/step
# 1/1 [==============================] - 0s 206ms/step
# 1/1 [==============================] - 0s 198ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 195ms/step
# successfully optimized portfolio weights
# 1/1 [==============================] - 0s 198ms/step
# 1/1 [==============================] - 0s 198ms/step
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 422ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 198ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 197ms/step
# successfully optimized portfolio weights
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 408ms/step
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 209ms/step
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 198ms/step
# 1/1 [==============================] - 0s 412ms/step
# 1/1 [==============================] - 0s 192ms/step
# successfully optimized portfolio weights
# CPU times: total: 43.2 s
# Wall time: 1min 23s

# %%
# %%time
display_backtest_results(
    [weight_LSTM,
     weight_LSTM_return,
     weight_LSTM_convex,
     # weight_LSTM_reg,
     weight_LSTM_sortino,
     weight_LSTM_sortino_convex,
    ],
    ["LSTM_paper", "LSTM_return", "LSTM_convex", 
     # "LSTM_l2reg", 
     "LSTM_sortino", "LSTM_sortino_convex"
    ]
)
# Out:
#                                        LSTM_paper  LSTM_return  LSTM_convex  \
# avg annualized ret                       0.196748     0.165916     0.148312
# avg annualized std                       0.303979     0.220888     0.142589
# sharpe ratio                             0.647243     0.751134     1.040137
# adjusted sharpe ratio                    0.656156     0.685293    -3.535701
# skewness                                 1.093406     2.027347     6.115322
# excess kurtosis                          5.968335    14.524906   121.108538
# maximum drawdown                        -0.290893    -0.280263    -0.168196
# maximum drawdown length (days)         369.000000   500.000000   980.000000
# VaR (95%)                               -0.025345    -0.018498    -0.010330
# CVaR (95%)                              -0.039113    -0.027055    -0.015724
# effective number of uncorrelated bets    1.804577     2.022430     2.441638
#
#                                        LSTM_sortino  LSTM_sortino_convex
# avg annualized ret                         0.152123             0.168097
# avg annualized std                         0.430380             0.191001
# sharpe ratio                               0.353462             0.880083
# adjusted sharpe ratio                      0.357839            -1.572047
# skewness                                   1.831967             5.860871
# excess kurtosis                           18.353020           112.972325
# maximum drawdown                          -0.418081            -0.167424
# maximum drawdown length (days)          1359.000000           249.000000
# VaR (95%)                                 -0.037544            -0.013652
# CVaR (95%)                                -0.057474            -0.021197
# effective number of uncorrelated bets      1.895542             2.270678
# CPU times: total: 3.2 s
# Wall time: 5.3 s

# %% [markdown]
# # Improvement 2: Structural Change - Autoencoder

# %%
# %%time

tf.keras.utils.set_random_seed(110)
weight_LSTM_autoencoder = portfolio_paper.optimize("LSTM", period = 252, 
                                                   loss = "convex", 
                                                   structure_change = "autoencoder")
# Out:
# 1/1 [==============================] - 0s 219ms/step
# 1/1 [==============================] - 0s 207ms/step
# 1/1 [==============================] - 0s 206ms/step
# 1/1 [==============================] - 0s 206ms/step
# 1/1 [==============================] - 0s 213ms/step
# 1/1 [==============================] - 0s 211ms/step
# 1/1 [==============================] - 0s 211ms/step
# 1/1 [==============================] - 0s 209ms/step
# 1/1 [==============================] - 0s 227ms/step
# 1/1 [==============================] - 0s 218ms/step
# successfully optimized portfolio weights
# CPU times: total: 9.67 s
# Wall time: 17.7 s

# %%
# %%time
display_backtest_results(
    [weight_LSTM,
     weight_LSTM_autoencoder,
     weight_MRC,
    ],
    ["LSTM_paper", "LSTM_autoencoder", "minMRC"]
)
# Out:
#                                        LSTM_paper  LSTM_autoencoder     minMRC
# avg annualized ret                       0.196748          0.076716   0.035015
# avg annualized std                       0.303979          0.076734   0.030779
# sharpe ratio                             0.647243          0.999766   1.137634
# adjusted sharpe ratio                    0.656156          0.712341   0.228074
# skewness                                 1.093406          0.169065  -1.123463
# excess kurtosis                          5.968335          7.579461  10.876209
# maximum drawdown                        -0.290893         -0.129794  -0.070101
# maximum drawdown length (days)         369.000000        118.000000  96.000000
# VaR (95%)                               -0.025345         -0.007111  -0.002842
# CVaR (95%)                              -0.039113         -0.010651  -0.004429
# effective number of uncorrelated bets    1.804577          2.948473   1.906171
# CPU times: total: 1.17 s
# Wall time: 3.16 s

# %% [markdown]
# # Improvement 3: SAE_CNN_LSTM & SAE_3CNN_LSTM

# %%
# %%time

tf.keras.utils.set_random_seed(110)
weight_SAE_CNN_LSTM = portfolio_paper.optimize("LSTM", period = 252, 
                                               loss = "convex", structure_change = "SAE_CNN_LSTM")
weight_SAE_3CNN_LSTM = portfolio_paper.optimize("LSTM", period = 252, 
                                                loss = "convex", structure_change = "SAE_3CNN_LSTM")
# Out:
# 1/1 [==============================] - 0s 230ms/step
# 1/1 [==============================] - 0s 226ms/step
# 1/1 [==============================] - 0s 231ms/step
# 1/1 [==============================] - 0s 232ms/step
# 1/1 [==============================] - 0s 228ms/step
# 1/1 [==============================] - 0s 249ms/step
# 1/1 [==============================] - 0s 228ms/step
# 1/1 [==============================] - 0s 224ms/step
# 1/1 [==============================] - 0s 230ms/step
# 1/1 [==============================] - 0s 229ms/step
# successfully optimized portfolio weights
# 1/1 [==============================] - 0s 242ms/step
# 1/1 [==============================] - 0s 245ms/step
# 1/1 [==============================] - 0s 247ms/step
# 1/1 [==============================] - 0s 264ms/step
# 1/1 [==============================] - 0s 244ms/step
# 1/1 [==============================] - 0s 251ms/step
# 1/1 [==============================] - 0s 240ms/step
# 1/1 [==============================] - 0s 254ms/step
# 1/1 [==============================] - 0s 251ms/step
# 1/1 [==============================] - 0s 244ms/step
# successfully optimized portfolio weights
# CPU times: total: 17.8 s
# Wall time: 40.3 s

# %%
# %%time
display_backtest_results(
    [weight_LSTM,
     weight_SAE_CNN_LSTM,
     weight_SAE_3CNN_LSTM
    ],
    ["LSTM_paper", "SAE_CNN_LSTM", "SAE_3CNN_LSTM"]
)
# Out:
#                                        LSTM_paper  SAE_CNN_LSTM  SAE_3CNN_LSTM
# avg annualized ret                       0.196748      0.076254       0.091081
# avg annualized std                       0.303979      0.090684       0.115568
# sharpe ratio                             0.647243      0.840875       0.788114
# adjusted sharpe ratio                    0.656156      0.709418       0.506980
# skewness                                 1.093406      0.652671       1.496070
# excess kurtosis                          5.968335      8.411150      21.376578
# maximum drawdown                        -0.290893     -0.139872      -0.146709
# maximum drawdown length (days)         369.000000    106.000000     104.000000
# VaR (95%)                               -0.025345     -0.008244      -0.009876
# CVaR (95%)                              -0.039113     -0.012112      -0.016817
# effective number of uncorrelated bets    1.804577      2.778033       2.533030
# CPU times: total: 1.84 s
# Wall time: 3.25 s

# %% [markdown]
# # Improvement 4: Double LSTM

# %%
# %%time

tf.keras.utils.set_random_seed(100)
weight_DOUBLE_LSTM = portfolio_paper.optimize("LSTM", period = 252, 
                                              loss = "convex", 
                                              structure_change = "DOUBLE_LSTM")  
weight_DOUBLE_LSTM_reg = portfolio_paper.optimize("LSTM", period = 252, 
                                                  loss = "convex", 
                                                  structure_change = "DOUBLE_LSTM", 
                                                  reg= True)
# Out:
# 1/1 [==============================] - 0s 201ms/step
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 200ms/step
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 216ms/step
# 1/1 [==============================] - 0s 197ms/step
# successfully optimized portfolio weights
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 198ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 207ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 216ms/step
# 1/1 [==============================] - 0s 207ms/step
# successfully optimized portfolio weights
# CPU times: total: 20.6 s
# Wall time: 32.4 s

# %%
# %%time
display_backtest_results(
    [weight_LSTM,
     weight_DOUBLE_LSTM,
     weight_DOUBLE_LSTM_reg
    ],
    ["LSTM_paper", "DOUBLE_LSTM", "DOUBLE_LSTM_reg"]
)
# Out:
#                                        LSTM_paper  DOUBLE_LSTM  \
# avg annualized ret                       0.196748     0.151832
# avg annualized std                       0.303979     0.196077
# sharpe ratio                             0.647243     0.774350
# adjusted sharpe ratio                    0.656156    -1.847790
# skewness                                 1.093406     7.915845
# excess kurtosis                          5.968335   176.426202
# maximum drawdown                        -0.290893    -0.196689
# maximum drawdown length (days)         369.000000   249.000000
# VaR (95%)                               -0.025345    -0.013204
# CVaR (95%)                              -0.039113    -0.021909
# effective number of uncorrelated bets    1.804577     2.442475
#
#                                        DOUBLE_LSTM_reg
# avg annualized ret                            0.175648
# avg annualized std                            0.213193
# sharpe ratio                                  0.823894
# adjusted sharpe ratio                         0.756352
# skewness                                      1.940310
# excess kurtosis                              12.318700
# maximum drawdown                             -0.167582
# maximum drawdown length (days)              132.000000
# VaR (95%)                                    -0.017066
# CVaR (95%)                                   -0.023809
# effective number of uncorrelated bets         1.870697
# CPU times: total: 2.08 s
# Wall time: 3.42 s

# %% [markdown]
# # Improvement 5: Bi-LSTM

# %%
# %%time

tf.keras.utils.set_random_seed(100)
weight_BiLSTM = portfolio_paper.optimize("LSTM", period = 252, 
                                              loss = "convex", 
                                              structure_change = "BiLSTM")  
weight_BiLSTM_sortino_convex = portfolio_paper.optimize("LSTM", period = 252, 
                                              loss = "sortino_convex", 
                                              structure_change = "BiLSTM")
# Out:
# 1/1 [==============================] - 0s 359ms/step
# 1/1 [==============================] - 0s 344ms/step
# 1/1 [==============================] - 0s 348ms/step
# 1/1 [==============================] - 0s 349ms/step
# 1/1 [==============================] - 0s 353ms/step
# 1/1 [==============================] - 0s 377ms/step
# 1/1 [==============================] - 0s 344ms/step
# 1/1 [==============================] - 0s 345ms/step
# 1/1 [==============================] - 0s 356ms/step
# 1/1 [==============================] - 0s 349ms/step
# successfully optimized portfolio weights
# 1/1 [==============================] - 0s 343ms/step
# 1/1 [==============================] - 0s 376ms/step
# 1/1 [==============================] - 0s 346ms/step
# 1/1 [==============================] - 0s 343ms/step
# 1/1 [==============================] - 0s 353ms/step
# 1/1 [==============================] - 1s 597ms/step
# 1/1 [==============================] - 0s 349ms/step
# 1/1 [==============================] - 1s 622ms/step
# 1/1 [==============================] - 0s 350ms/step
# 1/1 [==============================] - 0s 346ms/step
# successfully optimized portfolio weights
# CPU times: total: 29.3 s
# Wall time: 55.9 s

# %%
# %%time
display_backtest_results(
    [weight_LSTM,
     weight_BiLSTM,
     weight_BiLSTM_sortino
    ],
    ["LSTM_paper", "BiLSTM", "BiLSTM_sortino_convex"]
)
# Out:
#                                        LSTM_paper     BiLSTM  \
# avg annualized ret                       0.196748   0.036678
# avg annualized std                       0.303979   0.039537
# sharpe ratio                             0.647243   0.927693
# adjusted sharpe ratio                    0.656156  -0.023128
# skewness                                 1.093406  -1.104582
# excess kurtosis                          5.968335  23.819570
# maximum drawdown                        -0.290893  -0.096594
# maximum drawdown length (days)         369.000000  93.000000
# VaR (95%)                               -0.025345  -0.003334
# CVaR (95%)                              -0.039113  -0.005628
# effective number of uncorrelated bets    1.804577   1.404672
#
#                                        BiLSTM_sortino_convex
# avg annualized ret                                  0.035372
# avg annualized std                                  0.111285
# sharpe ratio                                        0.317850
# adjusted sharpe ratio                               0.191737
# skewness                                           -1.430355
# excess kurtosis                                    76.255010
# maximum drawdown                                   -0.352176
# maximum drawdown length (days)                    625.000000
# VaR (95%)                                          -0.005313
# CVaR (95%)                                         -0.015700
# effective number of uncorrelated bets               1.297605
# CPU times: total: 1.97 s
# Wall time: 3.45 s
